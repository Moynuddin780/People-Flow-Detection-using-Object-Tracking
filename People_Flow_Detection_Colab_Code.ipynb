# %% [markdown]
# # People Flow Detection using Object Tracking Visualization
#
# ---
#
# ## 📋 Overview
# This project implements a sophisticated system to detect and count people entering and exiting a defined area in a video using object tracking and heatmap visualization. It leverages **YOLOv8** for detection and **ByteTrack** for tracking, complemented by a heatmap to illustrate movement intensity. Bounding boxes are drawn in green with unique track IDs for clear identification.
#
# ---
#
# ## 🔍 Detection Method
# - **Model**: YOLOv8 (pre-trained `yolov8n.pt`) for detecting persons (class 0).
# - **Tracker**: ByteTrack ensures consistent tracking of individuals across frames.
# - **Libraries**: Utilizes OpenCV, Ultralytics YOLO, Supervision, and Matplotlib for processing and visualization.
#
# ---
#
# ## 📏 Line Coordinates
# - **Upper Line (IN)**: Positioned at `y = frame height / 3`, marked in **blue**.
# - **Lower Line (OUT)**: Positioned at `y = 2 * frame height / 3`, marked in **red**.
# - Defined using the [PolygonZone](https://polygonzone.roboflow.com/) framework.
#
# ---
#
# ## 🧮 Logic for IN/OUT Counting
# - **IN**: A person is counted as entering when their trajectory moves downward, crossing the upper line (y-coordinate transitions from below `LINE_Y1` to at or above `LINE_Y1`).
# - **OUT**: A person is counted as exiting when their trajectory moves upward, crossing the lower line (y-coordinate transitions from above `LINE_Y2` to at or below `LINE_Y2`).
# - The system tracks the center y-coordinate of bounding boxes to determine direction, updating counters based on these crossings.
#
# ---
#
# ## 📤 Output
# - **Video**: `output_video.mp4` displays bounding boxes, track IDs, color-coded lines, and live IN/OUT counters.
# - **Heatmap**: `heatmap.png` visualizes movement intensity using bounding box center points, normalized with a 'hot' colormap.
#
# ---
#
# ## 📥 Input & Output Files
# - **Input Video**: Paste your video file path here (e.g., `/content/people-walking video.mp4`).
# - **Output People Flow Detection Video**: Save as `output_video.mp4`.
# - **Heatmap Image**: Save as `heatmap.png`.
#
# ---
#
# ## 🚀 Setup
# 1. Install required dependencies in your Colab environment:
#    ```bash
#    !pip install opencv-python numpy ultralytics supervision matplotlib

# %% [markdown]
# # Import Libraries

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from supervision import ByteTrack, Color
import supervision as sv
import matplotlib.pyplot as plt

# %% [markdown]
# # Load YOLOv8n model

# %%
model = YOLO("yolov8n.pt")

# %% [markdown]
# # Video input

# %%
video_path = "/content/people-walking video.mp4"
cap = cv2.VideoCapture(video_path)

# %% [markdown]
# # Get video properties

# %%
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# %% [markdown]
# # Define two horizontal lines

# %%
LINE_Y1 = height // 3  # Upper line
LINE_Y2 = 2 * height // 3  # Lower line
LINE_COLOR_UP = Color.BLUE
LINE_COLOR_DOWN = Color.RED

# %% [markdown]
# # Initialize counters and tracker

# %%
in_count = 0
out_count = 0
tracker = ByteTrack()
track_history = {}
heatmap = np.zeros((height, width), dtype=np.float32)

# %% [markdown]
# # Video writer for output

# %%
output_path = "output_video.mp4"
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# %% [markdown]
# # Line coordinates for counting

# %%
line1 = sv.LineZone(start=sv.Point(0, LINE_Y1), end=sv.Point(width, LINE_Y1))
line2 = sv.LineZone(start=sv.Point(0, LINE_Y2), end=sv.Point(width, LINE_Y2))

def process_frame(frame, frame_num):
    global in_count, out_count

    # Run YOLO detection
    results = model(frame, classes=[0])[0]  # Class 0 for person
    detections = sv.Detections.from_ultralytics(results)

    # Update tracker
    detections = tracker.update_with_detections(detections)

    # Draw bounding boxes and IDs
    annotated_frame = frame.copy()
    for box, track_id in zip(detections.xyxy, detections.tracker_id):
        x1, y1, x2, y2 = map(int, box)
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2

        # Update track history with (x, y) coordinates
        if track_id not in track_history:
            track_history[track_id] = []
        track_history[track_id].append((center_x, center_y))

        # Draw bounding box and ID
        cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(annotated_frame, f"ID: {track_id}", (x1, y1-10),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Count IN/OUT
        if len(track_history[track_id]) > 1:
            prev_x, prev_y = track_history[track_id][-2]
            curr_x, curr_y = track_history[track_id][-1]

            # IN: Moving down, crossing upper line
            if prev_y < LINE_Y1 and curr_y >= LINE_Y1:
                in_count += 1
            # OUT: Moving up, crossing lower line
            elif prev_y > LINE_Y2 and curr_y <= LINE_Y2:
                out_count += 1
     # Draw lines
    cv2.line(annotated_frame, (0, LINE_Y1), (width, LINE_Y1), LINE_COLOR_UP.as_bgr(), 2)
    cv2.line(annotated_frame, (0, LINE_Y2), (width, LINE_Y2), LINE_COLOR_DOWN.as_bgr(), 2)

    # Display counters
    cv2.putText(annotated_frame, f"IN: {in_count}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(annotated_frame, f"OUT: {out_count}", (10, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    return annotated_frame

# %% [markdown]
# # Process video

# %%
frame_num = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    annotated_frame = process_frame(frame, frame_num)
    out.write(annotated_frame)
    frame_num += 1
# Out:
# 0: 384x640 37 persons, 95.4ms
# Speed: 3.6ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 108.7ms
# Speed: 2.7ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 106.4ms
# Speed: 2.2ms preprocess, 106.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 108.9ms
# Speed: 2.8ms preprocess, 108.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 95.6ms
# Speed: 3.0ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 96.5ms
# Speed: 2.2ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 97.8ms
# Speed: 2.2ms preprocess, 97.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 96.4ms
# Speed: 2.2ms preprocess, 96.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 98.8ms
# Speed: 2.5ms preprocess, 98.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 96.9ms
# Speed: 3.0ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 107.1ms
# Speed: 2.8ms preprocess, 107.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 98.4ms
# Speed: 2.3ms preprocess, 98.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 97.7ms
# Speed: 2.2ms preprocess, 97.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 101.0ms
# Speed: 2.5ms preprocess, 101.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 99.4ms
# Speed: 2.8ms preprocess, 99.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 97.8ms
# Speed: 2.9ms preprocess, 97.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 96.8ms
# Speed: 2.7ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 92.2ms
# Speed: 2.3ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 97.1ms
# Speed: 2.6ms preprocess, 97.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 98.1ms
# Speed: 2.5ms preprocess, 98.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 95.8ms
# Speed: 2.5ms preprocess, 95.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 96.2ms
# Speed: 2.7ms preprocess, 96.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 99.6ms
# Speed: 2.3ms preprocess, 99.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 96.6ms
# Speed: 2.6ms preprocess, 96.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 94.5ms
# Speed: 2.3ms preprocess, 94.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 92.0ms
# Speed: 2.2ms preprocess, 92.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 95.9ms
# Speed: 2.2ms preprocess, 95.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 102.7ms
# Speed: 2.5ms preprocess, 102.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 98.1ms
# Speed: 2.7ms preprocess, 98.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 94.1ms
# Speed: 2.5ms preprocess, 94.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 93.4ms
# Speed: 2.1ms preprocess, 93.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 91.6ms
# Speed: 2.3ms preprocess, 91.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 96.2ms
# Speed: 2.2ms preprocess, 96.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 95.1ms
# Speed: 2.2ms preprocess, 95.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 101.5ms
# Speed: 2.3ms preprocess, 101.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 104.0ms
# Speed: 2.3ms preprocess, 104.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 96.9ms
# Speed: 2.1ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 96.9ms
# Speed: 2.2ms preprocess, 96.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 95.0ms
# Speed: 2.7ms preprocess, 95.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 95.0ms
# Speed: 2.1ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 95.9ms
# Speed: 2.4ms preprocess, 95.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 91.9ms
# Speed: 2.1ms preprocess, 91.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 96.4ms
# Speed: 2.1ms preprocess, 96.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 103.4ms
# Speed: 2.3ms preprocess, 103.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 97.9ms
# Speed: 2.4ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 101.1ms
# Speed: 2.2ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 97.6ms
# Speed: 2.3ms preprocess, 97.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 90.5ms
# Speed: 2.2ms preprocess, 90.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 95.2ms
# Speed: 2.4ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 95.9ms
# Speed: 3.5ms preprocess, 95.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 98.0ms
# Speed: 2.7ms preprocess, 98.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 129.8ms
# Speed: 2.4ms preprocess, 129.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 127.0ms
# Speed: 2.4ms preprocess, 127.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 121.7ms
# Speed: 2.4ms preprocess, 121.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 110.8ms
# Speed: 2.3ms preprocess, 110.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 112.6ms
# Speed: 2.2ms preprocess, 112.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 118.0ms
# Speed: 2.2ms preprocess, 118.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 122.8ms
# Speed: 2.4ms preprocess, 122.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 137.2ms
# Speed: 2.5ms preprocess, 137.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 134.6ms
# Speed: 2.4ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 97.0ms
# Speed: 2.9ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 96.0ms
# Speed: 2.4ms preprocess, 96.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 93.1ms
# Speed: 2.1ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 98.3ms
# Speed: 2.1ms preprocess, 98.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 97.6ms
# Speed: 2.1ms preprocess, 97.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 100.3ms
# Speed: 2.2ms preprocess, 100.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 97.6ms
# Speed: 3.1ms preprocess, 97.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 96.9ms
# Speed: 3.8ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 93.7ms
# Speed: 2.5ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 96.7ms
# Speed: 2.2ms preprocess, 96.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 95.2ms
# Speed: 2.1ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 95.3ms
# Speed: 2.3ms preprocess, 95.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 92.2ms
# Speed: 2.2ms preprocess, 92.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 93.3ms
# Speed: 2.1ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 42 persons, 102.1ms
# Speed: 4.4ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 91.2ms
# Speed: 2.3ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 91.1ms
# Speed: 2.2ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 42 persons, 96.8ms
# Speed: 2.0ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 97.6ms
# Speed: 2.0ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 95.0ms
# Speed: 2.3ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 92.3ms
# Speed: 2.2ms preprocess, 92.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 93.4ms
# Speed: 2.1ms preprocess, 93.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 99.4ms
# Speed: 2.4ms preprocess, 99.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 94.9ms
# Speed: 2.6ms preprocess, 94.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 95.4ms
# Speed: 2.3ms preprocess, 95.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 99.0ms
# Speed: 2.2ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 94.7ms
# Speed: 2.2ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 91.2ms
# Speed: 2.1ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 98.1ms
# Speed: 2.1ms preprocess, 98.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 101.1ms
# Speed: 2.1ms preprocess, 101.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 105.9ms
# Speed: 2.2ms preprocess, 105.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 96.5ms
# Speed: 2.5ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 96.6ms
# Speed: 2.3ms preprocess, 96.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 96.3ms
# Speed: 2.1ms preprocess, 96.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 96.1ms
# Speed: 2.1ms preprocess, 96.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 93.5ms
# Speed: 2.4ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 95.5ms
# Speed: 2.4ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 101.1ms
# Speed: 2.6ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 97.0ms
# Speed: 2.1ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 91.7ms
# Speed: 2.6ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 92.9ms
# Speed: 2.3ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 94.8ms
# Speed: 2.5ms preprocess, 94.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 97.4ms
# Speed: 2.5ms preprocess, 97.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 97.1ms
# Speed: 2.4ms preprocess, 97.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 98.9ms
# Speed: 3.0ms preprocess, 98.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 97.6ms
# Speed: 2.5ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 95.8ms
# Speed: 2.5ms preprocess, 95.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 104.3ms
# Speed: 3.1ms preprocess, 104.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 94.9ms
# Speed: 3.2ms preprocess, 94.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 97.4ms
# Speed: 3.4ms preprocess, 97.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 95.8ms
# Speed: 2.5ms preprocess, 95.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 98.9ms
# Speed: 2.4ms preprocess, 98.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 96.2ms
# Speed: 4.6ms preprocess, 96.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 98.7ms
# Speed: 2.5ms preprocess, 98.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 102.2ms
# Speed: 2.4ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 104.0ms
# Speed: 2.3ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 96.1ms
# Speed: 2.3ms preprocess, 96.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 99.0ms
# Speed: 2.2ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 97.1ms
# Speed: 2.5ms preprocess, 97.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 98.8ms
# Speed: 2.3ms preprocess, 98.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 102.0ms
# Speed: 3.5ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 101.2ms
# Speed: 2.3ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 102.7ms
# Speed: 2.2ms preprocess, 102.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 102.3ms
# Speed: 3.7ms preprocess, 102.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 96.9ms
# Speed: 2.7ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 98.1ms
# Speed: 2.8ms preprocess, 98.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 98.0ms
# Speed: 2.5ms preprocess, 98.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 99.3ms
# Speed: 2.5ms preprocess, 99.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 98.9ms
# Speed: 2.5ms preprocess, 98.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 97.3ms
# Speed: 2.6ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 98.2ms
# Speed: 2.4ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 105.4ms
# Speed: 2.5ms preprocess, 105.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 95.4ms
# Speed: 2.2ms preprocess, 95.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 97.2ms
# Speed: 2.3ms preprocess, 97.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 94.8ms
# Speed: 2.4ms preprocess, 94.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 96.5ms
# Speed: 2.7ms preprocess, 96.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 92.1ms
# Speed: 2.5ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 99.4ms
# Speed: 2.8ms preprocess, 99.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 100.8ms
# Speed: 2.1ms preprocess, 100.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 124.6ms
# Speed: 2.3ms preprocess, 124.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 134.2ms
# Speed: 2.8ms preprocess, 134.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 138.2ms
# Speed: 2.3ms preprocess, 138.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 118.5ms
# Speed: 2.4ms preprocess, 118.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 114.3ms
# Speed: 2.2ms preprocess, 114.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 121.9ms
# Speed: 2.2ms preprocess, 121.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 133.5ms
# Speed: 4.3ms preprocess, 133.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 119.0ms
# Speed: 2.3ms preprocess, 119.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 123.9ms
# Speed: 2.3ms preprocess, 123.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 127.7ms
# Speed: 2.3ms preprocess, 127.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 94.0ms
# Speed: 2.1ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 92.9ms
# Speed: 2.2ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 99.7ms
# Speed: 2.3ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 99.8ms
# Speed: 2.3ms preprocess, 99.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 103.1ms
# Speed: 2.5ms preprocess, 103.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 96.1ms
# Speed: 2.3ms preprocess, 96.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 96.9ms
# Speed: 2.5ms preprocess, 96.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 103.9ms
# Speed: 2.3ms preprocess, 103.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 91.1ms
# Speed: 3.3ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 96.0ms
# Speed: 2.6ms preprocess, 96.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 94.7ms
# Speed: 2.4ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 93.2ms
# Speed: 3.0ms preprocess, 93.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 99.7ms
# Speed: 2.5ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 94.6ms
# Speed: 2.7ms preprocess, 94.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 95.0ms
# Speed: 2.5ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 103.5ms
# Speed: 2.4ms preprocess, 103.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 93.4ms
# Speed: 2.2ms preprocess, 93.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 100.7ms
# Speed: 2.3ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 101.8ms
# Speed: 2.6ms preprocess, 101.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 98.5ms
# Speed: 2.7ms preprocess, 98.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 105.6ms
# Speed: 2.3ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 94.5ms
# Speed: 2.4ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 94.4ms
# Speed: 2.6ms preprocess, 94.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 105.5ms
# Speed: 2.6ms preprocess, 105.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 103.2ms
# Speed: 3.1ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 94.7ms
# Speed: 2.4ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 95.4ms
# Speed: 2.4ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 93.9ms
# Speed: 2.6ms preprocess, 93.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 100.7ms
# Speed: 2.5ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 97.1ms
# Speed: 2.6ms preprocess, 97.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 96.9ms
# Speed: 2.2ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 101.5ms
# Speed: 3.5ms preprocess, 101.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 97.8ms
# Speed: 2.6ms preprocess, 97.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 100.5ms
# Speed: 3.2ms preprocess, 100.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 100.0ms
# Speed: 2.5ms preprocess, 100.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 100.8ms
# Speed: 3.3ms preprocess, 100.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 105.1ms
# Speed: 2.6ms preprocess, 105.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 106.7ms
# Speed: 2.6ms preprocess, 106.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 98.1ms
# Speed: 2.2ms preprocess, 98.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 104.5ms
# Speed: 2.2ms preprocess, 104.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 99.8ms
# Speed: 2.3ms preprocess, 99.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 99.4ms
# Speed: 2.2ms preprocess, 99.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 96.9ms
# Speed: 2.2ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 97.6ms
# Speed: 2.4ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 98.0ms
# Speed: 2.3ms preprocess, 98.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 96.4ms
# Speed: 2.5ms preprocess, 96.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 97.2ms
# Speed: 2.4ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 104.8ms
# Speed: 2.9ms preprocess, 104.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 100.2ms
# Speed: 2.3ms preprocess, 100.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 98.7ms
# Speed: 2.2ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 97.9ms
# Speed: 2.5ms preprocess, 97.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 97.6ms
# Speed: 2.3ms preprocess, 97.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 97.5ms
# Speed: 2.2ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 96.2ms
# Speed: 2.3ms preprocess, 96.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 98.9ms
# Speed: 2.3ms preprocess, 98.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 104.0ms
# Speed: 2.8ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 97.5ms
# Speed: 2.3ms preprocess, 97.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 97.2ms
# Speed: 2.2ms preprocess, 97.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 97.4ms
# Speed: 2.6ms preprocess, 97.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 95.7ms
# Speed: 2.2ms preprocess, 95.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 95.0ms
# Speed: 2.1ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 100.4ms
# Speed: 2.2ms preprocess, 100.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 93.8ms
# Speed: 2.3ms preprocess, 93.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 101.9ms
# Speed: 3.5ms preprocess, 101.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 90.2ms
# Speed: 2.5ms preprocess, 90.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 98.6ms
# Speed: 2.3ms preprocess, 98.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 93.3ms
# Speed: 1.7ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 95.8ms
# Speed: 2.2ms preprocess, 95.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 101.8ms
# Speed: 2.4ms preprocess, 101.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 99.2ms
# Speed: 2.1ms preprocess, 99.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 97.6ms
# Speed: 2.2ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 98.1ms
# Speed: 2.5ms preprocess, 98.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 96.8ms
# Speed: 2.6ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 99.5ms
# Speed: 3.7ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 96.2ms
# Speed: 3.2ms preprocess, 96.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 98.8ms
# Speed: 2.3ms preprocess, 98.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 101.2ms
# Speed: 2.3ms preprocess, 101.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 102.6ms
# Speed: 2.2ms preprocess, 102.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 94.9ms
# Speed: 2.3ms preprocess, 94.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 126.8ms
# Speed: 2.2ms preprocess, 126.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 126.7ms
# Speed: 2.3ms preprocess, 126.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 130.0ms
# Speed: 4.8ms preprocess, 130.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 112.8ms
# Speed: 2.2ms preprocess, 112.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 122.2ms
# Speed: 2.4ms preprocess, 122.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 133.0ms
# Speed: 2.3ms preprocess, 133.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 133.5ms
# Speed: 2.4ms preprocess, 133.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 130.0ms
# Speed: 2.2ms preprocess, 130.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 133.1ms
# Speed: 2.4ms preprocess, 133.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 95.6ms
# Speed: 2.3ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 96.8ms
# Speed: 2.7ms preprocess, 96.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 92.7ms
# Speed: 2.0ms preprocess, 92.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 98.4ms
# Speed: 2.2ms preprocess, 98.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 94.1ms
# Speed: 2.3ms preprocess, 94.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 92.8ms
# Speed: 2.7ms preprocess, 92.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 98.6ms
# Speed: 2.4ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 97.4ms
# Speed: 2.4ms preprocess, 97.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 91.2ms
# Speed: 2.5ms preprocess, 91.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 99.5ms
# Speed: 2.5ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 100.9ms
# Speed: 2.5ms preprocess, 100.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 103.2ms
# Speed: 2.6ms preprocess, 103.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 101.0ms
# Speed: 2.4ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 93.1ms
# Speed: 2.5ms preprocess, 93.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 96.6ms
# Speed: 2.4ms preprocess, 96.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 98.4ms
# Speed: 2.7ms preprocess, 98.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 97.0ms
# Speed: 2.8ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 96.7ms
# Speed: 3.8ms preprocess, 96.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 100.2ms
# Speed: 3.5ms preprocess, 100.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 97.9ms
# Speed: 2.4ms preprocess, 97.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 106.2ms
# Speed: 2.5ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 98.6ms
# Speed: 2.4ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 133.3ms
# Speed: 4.3ms preprocess, 133.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 126.6ms
# Speed: 2.3ms preprocess, 126.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 156.4ms
# Speed: 4.2ms preprocess, 156.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 185.1ms
# Speed: 3.3ms preprocess, 185.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 124.9ms
# Speed: 2.6ms preprocess, 124.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 261.4ms
# Speed: 2.4ms preprocess, 261.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 202.9ms
# Speed: 2.7ms preprocess, 202.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 174.2ms
# Speed: 2.4ms preprocess, 174.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 134.3ms
# Speed: 9.6ms preprocess, 134.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 157.7ms
# Speed: 3.6ms preprocess, 157.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 164.2ms
# Speed: 2.4ms preprocess, 164.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 127.6ms
# Speed: 2.4ms preprocess, 127.6ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 206.4ms
# Speed: 2.3ms preprocess, 206.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 129.5ms
# Speed: 2.5ms preprocess, 129.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 121.0ms
# Speed: 2.4ms preprocess, 121.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 209.7ms
# Speed: 2.2ms preprocess, 209.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 153.7ms
# Speed: 2.4ms preprocess, 153.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 199.6ms
# Speed: 2.7ms preprocess, 199.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 189.3ms
# Speed: 2.8ms preprocess, 189.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 142.1ms
# Speed: 2.4ms preprocess, 142.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 151.6ms
# Speed: 2.5ms preprocess, 151.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 135.2ms
# Speed: 2.5ms preprocess, 135.2ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 267.0ms
# Speed: 2.5ms preprocess, 267.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 157.9ms
# Speed: 2.5ms preprocess, 157.9ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 123.6ms
# Speed: 2.4ms preprocess, 123.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 95.7ms
# Speed: 2.4ms preprocess, 95.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 99.6ms
# Speed: 2.5ms preprocess, 99.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 99.1ms
# Speed: 2.8ms preprocess, 99.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 108.4ms
# Speed: 6.4ms preprocess, 108.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 97.5ms
# Speed: 2.6ms preprocess, 97.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 94.4ms
# Speed: 2.3ms preprocess, 94.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 94.1ms
# Speed: 2.1ms preprocess, 94.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 98.3ms
# Speed: 3.7ms preprocess, 98.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 99.2ms
# Speed: 3.1ms preprocess, 99.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 95.6ms
# Speed: 2.0ms preprocess, 95.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 96.6ms
# Speed: 2.5ms preprocess, 96.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 106.1ms
# Speed: 2.4ms preprocess, 106.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 104.1ms
# Speed: 2.2ms preprocess, 104.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 135.4ms
# Speed: 2.3ms preprocess, 135.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 126.5ms
# Speed: 5.3ms preprocess, 126.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 130.9ms
# Speed: 2.7ms preprocess, 130.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 110.3ms
# Speed: 2.2ms preprocess, 110.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 136.2ms
# Speed: 2.3ms preprocess, 136.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 126.7ms
# Speed: 3.7ms preprocess, 126.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 129.6ms
# Speed: 3.7ms preprocess, 129.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 120.6ms
# Speed: 2.5ms preprocess, 120.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 139.2ms
# Speed: 2.2ms preprocess, 139.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 99.9ms
# Speed: 2.6ms preprocess, 99.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 95.4ms
# Speed: 2.6ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 105.2ms
# Speed: 2.6ms preprocess, 105.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 93.7ms
# Speed: 2.6ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 101.0ms
# Speed: 2.2ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 93.9ms
# Speed: 2.2ms preprocess, 93.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 98.2ms
# Speed: 2.2ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 98.7ms
# Speed: 2.4ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 101.2ms
# Speed: 2.3ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 103.7ms
# Speed: 3.6ms preprocess, 103.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 98.2ms
# Speed: 2.4ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 91.4ms
# Speed: 2.3ms preprocess, 91.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 92.7ms
# Speed: 2.8ms preprocess, 92.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 91.7ms
# Speed: 2.6ms preprocess, 91.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 89.4ms
# Speed: 2.2ms preprocess, 89.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 94.2ms
# Speed: 2.1ms preprocess, 94.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 99.9ms
# Speed: 2.3ms preprocess, 99.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 102.5ms
# Speed: 2.1ms preprocess, 102.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 104.4ms
# Speed: 2.4ms preprocess, 104.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 95.6ms
# Speed: 2.3ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 98.0ms
# Speed: 2.3ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 97.8ms
# Speed: 2.5ms preprocess, 97.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 94.4ms
# Speed: 2.5ms preprocess, 94.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 99.4ms
# Speed: 2.4ms preprocess, 99.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 99.8ms
# Speed: 2.7ms preprocess, 99.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 97.1ms
# Speed: 2.4ms preprocess, 97.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 100.7ms
# Speed: 2.4ms preprocess, 100.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 100.3ms
# Speed: 3.9ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 96.4ms
# Speed: 2.7ms preprocess, 96.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 96.5ms
# Speed: 2.4ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 92.6ms
# Speed: 2.4ms preprocess, 92.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 95.6ms
# Speed: 2.6ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 91.1ms
# Speed: 2.3ms preprocess, 91.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 94.7ms
# Speed: 2.7ms preprocess, 94.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 89.3ms
# Speed: 2.2ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# # Release video resources

# %%
cap.release()
out.release()

# %% [markdown]
# # Generate & save improved heatmap

# %%
heatmap = np.zeros((height, width), dtype=np.float32)
for track_id in track_history:
    for center_x, center_y in track_history[track_id]:
        if 0 <= center_y < height and 0 <= center_x < width:
            heatmap[int(center_y), int(center_x)] += 1

# %% [markdown]
# # Gaussian blur for smoothing

# %%
heatmap = cv2.GaussianBlur(heatmap, (21, 21), 10)

# Normalize and clip the heatmap
heatmap = np.clip(heatmap, 0, None)
if heatmap.max() > 0:
    heatmap = heatmap / heatmap.max()

# %% [markdown]
# # Visualize and save heatmap

# %%
plt.figure(figsize=(10, 6))
plt.imshow(heatmap, cmap='hot', interpolation='bilinear', vmin=0, vmax=0.8)
plt.colorbar(label='Intensity')
plt.title('People Movement Heatmap')
plt.axis('off')  # Hide axes for cleaner look
plt.savefig('heatmap.png', bbox_inches='tight', pad_inches=0)
plt.close()

# %%
## 📥 Input & Output Files

### 🎥 Input Video:
[![Input Video SS](https://github.com/Moynuddin780/People-Flow-Detection-using-Object-Tracking/blob/main/Input%20video%20SS.jpg)

### 🎥 Output Video:
[![Output Video SS](https://github.com/Moynuddin780/People-Flow-Detection-using-Object-Tracking/blob/main/Output%20ScreenShoot.jpg)
